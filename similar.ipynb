# %%
#モジュールインポート
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, TensorDataset
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %%
#使用デバイス判別
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("使用デバイス:", device)
# Out:
# 使用デバイス: cpu

# %%
def fix_seed(seed):
    # random
    random.seed(seed)
    # Numpy
    np.random.seed(seed)
    # Pytorch
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True

SEED = 42
fix_seed(SEED)

# %%
#データ読み込み
teams_data = pd.read_csv("drive/MyDrive/lab/similar_dataset/teams_packet01.csv")
meet_data = pd.read_csv("drive/MyDrive/lab/similar_dataset/meet_packet01.csv")
zoom_data = pd.read_csv("drive/MyDrive/lab/similar_dataset/zoom_packet01.csv")

teams_data = teams_data.head(100000)
meet_data = meet_data.head(100000)
zoom_data = zoom_data.head(100000)

"""
ipad_data[["link"]] = 0
iphone_data[["link"]] = 0
kirin_data[["link"]] = 0
rakko_data[["link"]] = 0
"""

datas = {1:teams_data, 2:meet_data, 3:zoom_data}
ips = ["192.168.100.12","192.168.100.12","192.168.100.12"]

for n,df in datas.items():
  """
  for index, data in df.iterrows():
    if data["Source"] == ips[n-1]:
      df.loc[index, "link"] = 0
    else:
      df.loc[index, "link"] = 1

  print(index)
  """

  df['rate'] = df['Length'] / (df['interval'] + 0.0000000000001)
  df['no_cum'] = df["cumbyte"] / n
  #df = df[["Length","interval","rate","link","no_cum"]]

  drop_index = df.index[df["Source"] == ips[n-1]]
  #drop_index = df.index[df["Destination"] == ips[n-1]]
  datas[n] = df.drop(drop_index)

num_feture=3

# %%
##データ正規化
#モジュールインポート
from sklearn.preprocessing import MinMaxScaler

labels = np.empty(0)
trains = np.empty(0)
data_num = 0
sequence = 10

for index in datas:
  data = datas[index]
  data = data[["Length","interval","rate"]].to_numpy()
  #data = data[["Length","interval","rate","no_cum"]].to_numpy()

  #データ正規化インスタンス生成
  std = MinMaxScaler()
  X = data
  X = std.fit_transform(X)
  data= X

  label_index = index
  num = len(datas[index])/sequence
  num = int(np.floor(num))
  data_num += num
  print("データ{}の要素数は{}です".format(label_index,num))

  label = np.full(num,label_index-1)
  labels = np.append(labels, label)
  trains = np.append(trains,data)

#trains = np.resize(trains, (data_num,sequence,num_feture))
trains = np.resize(trains, (data_num,1,sequence,num_feture))#CNNを使う際はこっち
target =labels
data_ = trains
# Out:
# データ1の要素数は5586です
# データ2の要素数は3847です
# データ3の要素数は5267です

# %%
from sklearn.model_selection import train_test_split
#データセットをトレーニングデータと検証データとテストデータに分割
X_train, X_test, y_train, y_test = train_test_split(data_, target, test_size = 0.2)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.2)

# Tensor型に変換
# 学習に入れるときはfloat型になっている必要があるのここで変換してしまう
X_train = torch.from_numpy(X_train).float()
y_train = torch.from_numpy(y_train).long()
X_valid = torch.from_numpy(X_valid).float()
y_valid = torch.from_numpy(y_valid).long()
X_test = torch.from_numpy(X_test).float()
y_test = torch.from_numpy(y_test).long()

# 2. Datasetの作成
train_dataset = TensorDataset(X_train, y_train)
valid_dataset = TensorDataset(X_valid, y_valid)
test_dataset = TensorDataset(X_test, y_test)

# 3. DataLoaderの作成
batch_size = 64
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
valid_dataloader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# 辞書型変数にまとめる
dataloaders_dict = {"train": train_dataloader, "val": valid_dataloader, "test": test_dataloader}

# %%
batch_iterator = iter(dataloaders_dict["train"])  # イテレータに変換
imges, labels = next(batch_iterator)  # 1番目の要素を取り出す
print("imges size = ", imges.size())
print("labels size = ", labels.size())
# Out:
# imges size =  torch.Size([64, 1, 10, 3])
# labels size =  torch.Size([64])

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(2, stride=2)
        #conv2d(input_cunnel,output_cunnel,karnel,padding)
        self.conv1 = nn.Conv2d(1,16,2,1)
        self.conv2 = nn.Conv2d(16,32,2,1)

        self.fc1 = nn.Linear(32 * 1 * (sequence-2), 120)
        self.fc2 = nn.Linear(120, 3)

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu(x)
        #x = self.pool(x)
        x = self.conv2(x)
        x = self.relu(x)
        x = self.pool(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.relu = nn.ReLU()
        self.pool = nn.MaxPool2d(2, stride=2)
        #conv2d(input_cunnel,output_cunnel,karnel,padding)
        self.conv1 = nn.Conv2d(1,16,2, padding= 1)
        self.conv2 = nn.Conv2d(16,32,2, padding= 1)

        self.fc1 = nn.Linear(32 * 6 * sequence // 5, 120)
        self.fc2 = nn.Linear(120, 3)

    def forward(self, x):
        x = self.conv1(x)
        x = self.relu(x)
        #x = self.pool(x)
        x = self.conv2(x)
        x = self.relu(x)
        x = self.pool(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# %%
class RNN(nn.Module):

    def __init__(self):
        super(RNN, self).__init__()
        self.seq_len = sequence            # 時系列のSequenceとしてLSTMに入力する
        self.feature_size = num_feture         # 特徴量の次元としてLSTMに入力する
        self.hidden_layer_size = 64   # 隠れ層のサイズ
        self.layers = 2          # LSTMのレイヤー数(LSTMを何層重ねるか)
        self.rnn = nn.RNN(self.feature_size,
                            self.hidden_layer_size,
                            num_layers = self.layers)

        self.fc = nn.Linear(self.hidden_layer_size, 3)

    def init_hidden(self, batch_size): # LSTMの隠れ層 hidden を初期化
        hedden = torch.zeros(self.layers, batch_size, self.hidden_layer_size)
        return hedden

    def forward(self, x):
        batch_size = x.shape[0]
        self.hidden = self.init_hidden(batch_size)

        x = x.view(batch_size, self.seq_len, self.feature_size)  # (Batch, Cannel, Height, Width) -> (Batch, Height, Width) = (Batch, Seqence, Feature)
                                                                 # 画像の Height を時系列のSequenceに、Width を特徴量の次元としてLSTMに入力する
        x = x.permute(1, 0, 2)                                   # (Batch, Seqence, Feature) -> (Seqence , Batch, Feature)

        rnn_out, h_n = self.rnn(x, self.hidden)    # LSTMの入力データのShapeは(Seqence, Batch, Feature)
                                                                 # (h_n) のShapeは (num_layers, batch, hidden_size)
        x = h_n[-1,:,:]                                          # lstm_layersの最後のレイヤーを取り出す  (B, h)
        x = self.fc(x)

        return x

# %%
class LSTM(nn.Module):

    def __init__(self):
        super(LSTM, self).__init__()
        self.seq_len = sequence            # 画像の Height を時系列のSequenceとしてLSTMに入力する
        self.feature_size = num_feture         # 画像の Width を特徴量の次元としてLSTMに入力する
        self.hidden_layer_size = 64   # 隠れ層のサイズ
        self.lstm_layers = 2          # LSTMのレイヤー数(LSTMを何層重ねるか)
        self.lstm = nn.LSTM(self.feature_size,
                            self.hidden_layer_size,
                            num_layers = self.lstm_layers)

        self.fc = nn.Linear(self.hidden_layer_size, 3)

    def init_hidden_cell(self, batch_size): # LSTMの隠れ層 hidden と記憶セル cell を初期化
        hedden = torch.zeros(self.lstm_layers, batch_size, self.hidden_layer_size)
        cell = torch.zeros(self.lstm_layers, batch_size, self.hidden_layer_size)
        return (hedden, cell)

    def forward(self, x):
        batch_size = x.shape[0]
        self.hidden_cell = self.init_hidden_cell(batch_size)

        x = x.view(batch_size, self.seq_len, self.feature_size)  # (Batch, Cannel, Height, Width) -> (Batch, Height, Width) = (Batch, Seqence, Feature)
                                                                 # 画像の Height を時系列のSequenceに、Width を特徴量の次元としてLSTMに入力する
        x = x.permute(1, 0, 2)                                   # (Batch, Seqence, Feature) -> (Seqence , Batch, Feature)

        lstm_out, (h_n, c_n) = self.lstm(x, self.hidden_cell)    # LSTMの入力データのShapeは(Seqence, Batch, Feature)
                                                                 # (h_n) のShapeは (num_layers, batch, hidden_size)
        x = h_n[-1,:,:]                                          # lstm_layersの最後のレイヤーを取り出す  (B, h)
        x = self.fc(x)

        return x

# %%
class GRU(nn.Module):

    def __init__(self):
        super(GRU, self).__init__()
        self.seq_len = sequence            # 時系列のSequenceとしてGRUに入力する
        self.feature_size = num_feture         # Width を特徴量の次元としてGRUに入力する
        self.hidden_layer_size = 32   # 隠れ層のサイズ
        self.gru_layers = 2          # GRUのレイヤー数(GRUを何層重ねるか)
        self.gru = nn.GRU(self.feature_size,
                            self.hidden_layer_size,
                            num_layers = self.gru_layers)

        self.fc = nn.Linear(self.hidden_layer_size, 3)

    def init_hidden(self, batch_size): # LSTMの隠れ層 hidden と記憶セル cell を初期化
        hedden = torch.zeros(self.gru_layers, batch_size, self.hidden_layer_size)
        return hedden

    def forward(self, x):
        batch_size = x.shape[0]
        self.hidden = self.init_hidden(batch_size)

        x = x.view(batch_size, self.seq_len, self.feature_size)  # (Batch, Cannel, Height, Width) -> (Batch, Height, Width) = (Batch, Seqence, Feature)
                                                                 # 画像の Height を時系列のSequenceに、Width を特徴量の次元としてLSTMに入力する
        x = x.permute(1, 0, 2)                                   # (Batch, Seqence, Feature) -> (Seqence , Batch, Feature)

        gru_out, h_n= self.gru(x, self.hidden)    # LSTMの入力データのShapeは(Seqence, Batch, Feature)
                                                                 # (h_n) のShapeは (num_layers, batch, hidden_size)
        x = h_n[-1,:,:]                                          # lstm_layersの最後のレイヤーを取り出す  (B, h)
        x = self.fc(x)

        return x

# %%
net = CNN()
print(net)
# Out:
# CNN(
#   (relu): ReLU()
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv1): Conv2d(1, 16, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(2, 2), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=384, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=3, bias=True)
# )

# %%
#損失関数の定義
criterion = nn.CrossEntropyLoss()

#最適化手法の定義
optimizer = optim.Adam(net.parameters(), lr=0.001)
#optimizer = optim.RMSprop(net0.parameters(), lr=0.001)

# %%
def train_model(net, dataloaders_dict, criterion, optimizer, device, num_epochs):

  train_loss_history = np.empty(0)
  train_acc_history = np.empty(0)
  val_loss_history = np.empty(0)
  val_acc_history = np.empty(0)
  preds_history = np.empty(0)

  for epoch in range(num_epochs):
      print("\n")
      print('Epoch {}/{}'.format(epoch+1, num_epochs))
      print('-------------')

  #epochごとの学習と検証のループ
      for phase in ['train', 'val']:
          if phase == 'train':   # モデルを訓練モードに設定
              net.train()
          else:                  # モデルを推論モードに設定
              net.eval()

          epoch_loss = 0.0       # エポックの損失和
          epoch_corrects = 0     # エポックの正解数

          # DataLoaderからデータをバッチごとに取り出す
          for inputs, labels in dataloaders_dict[phase]:

              optimizer.zero_grad()  # optimizerの初期化

              # 順伝播計算
              # 学習時のみ勾配を計算させる設定にする
              with torch.set_grad_enabled(phase == 'train'):
                  outputs = net(inputs)                 # 順伝播
                  loss = criterion(outputs, labels)     # 損失を計算
                  _, preds = torch.max(outputs, 1)      # ラベルを予測

                  # 訓練時はバックプロパゲーション
                  if phase == 'train':
                      loss.backward()                   # 逆伝搬の計算
                      optimizer.step()                  # パラメータの更新

                  # イテレーション結果の計算
                  # lossの合計を更新
                  epoch_loss += loss.item() * inputs.size(0)
                  # 正解数の合計を更新
                  epoch_corrects += torch.sum(preds == labels.data)
                  preds_history = np.append(preds_history, preds)

          # epochごとのlossと正解率を表示
          epoch_loss = epoch_loss / len(dataloaders_dict[phase].dataset)
          epoch_acc = epoch_corrects.double() / len(dataloaders_dict[phase].dataset)

          if phase == 'train':
            train_loss_history = np.append(train_loss_history, epoch_loss)
            train_acc_history = np.append(train_acc_history, epoch_acc)

          if phase == 'val':
            val_loss_history = np.append(val_loss_history, epoch_loss)
            val_acc_history = np.append(val_acc_history, epoch_acc)


          print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

  fig = plt.figure()
  axis1 = fig.subplots()
  #axis2 = axis1.twinx()
  x = np.arange(num_epochs)

  line1 = axis1.plot(x, train_acc_history, color='C0',label='train_acc')
  line2 = axis1.plot(x, val_acc_history, color='C1', label='val_acc')

  h1, l1 = axis1.get_legend_handles_labels()
  #h2, l2 = axis2.get_legend_handles_labels()
  axis1.legend(h1, l1, loc='lower right')
  #axis1.legend(h1+h2, l1+l2, loc='lower right')

  axis1.set_xlabel("epochs")
  axis1.set_ylabel("accuracy")
  axis1.grid(False)
  #axis2.set_ylabel("accuracy")
  plt.show()
  print(train_acc_history)

# %%
import time

# 処理前の時刻
t1 = time.time()

num_epochs = 100
train_model(net, dataloaders_dict, criterion, optimizer, device, num_epochs=num_epochs)

# 処理後の時刻
t2 = time.time()

# 経過時間を表示
elapsed_time = t2-t1
print(f"学習時間：{elapsed_time}")
# Out:
# Epoch 1/100
# -------------
# train Loss: 0.5311 Acc: 0.7930
# val Loss: 0.1329 Acc: 0.9554
#
#
# Epoch 2/100
# -------------
# train Loss: 0.0925 Acc: 0.9763
# val Loss: 0.0503 Acc: 0.9847
#
#
# Epoch 3/100
# -------------
# train Loss: 0.0607 Acc: 0.9849
# val Loss: 0.0378 Acc: 0.9885
#
#
# Epoch 4/100
# -------------
# train Loss: 0.0460 Acc: 0.9879
# val Loss: 0.0354 Acc: 0.9868
#
#
# Epoch 5/100
# -------------
# train Loss: 0.0378 Acc: 0.9905
# val Loss: 0.0295 Acc: 0.9919
#
#
# Epoch 6/100
# -------------
# train Loss: 0.0335 Acc: 0.9916
# val Loss: 0.0237 Acc: 0.9915
#
#
# Epoch 7/100
# -------------
# train Loss: 0.0295 Acc: 0.9916
# val Loss: 0.0344 Acc: 0.9894
#
#
# Epoch 8/100
# -------------
# train Loss: 0.0258 Acc: 0.9927
# val Loss: 0.0241 Acc: 0.9919
#
#
# Epoch 9/100
# -------------
# train Loss: 0.0243 Acc: 0.9932
# val Loss: 0.0183 Acc: 0.9945
#
#
# Epoch 10/100
# -------------
# train Loss: 0.0231 Acc: 0.9933
# val Loss: 0.0185 Acc: 0.9949
#
#
# Epoch 11/100
# -------------
# train Loss: 0.0195 Acc: 0.9944
# val Loss: 0.0176 Acc: 0.9936
#
#
# Epoch 12/100
# -------------
# train Loss: 0.0170 Acc: 0.9951
# val Loss: 0.0170 Acc: 0.9940
#
#
# Epoch 13/100
# -------------
# train Loss: 0.0142 Acc: 0.9957
# val Loss: 0.0155 Acc: 0.9957
#
#
# Epoch 14/100
# -------------
# train Loss: 0.0137 Acc: 0.9963
# val Loss: 0.0150 Acc: 0.9928
#
#
# Epoch 15/100
# -------------
# train Loss: 0.0116 Acc: 0.9966
# val Loss: 0.0137 Acc: 0.9966
#
#
# Epoch 16/100
# -------------
# train Loss: 0.0105 Acc: 0.9972
# val Loss: 0.0104 Acc: 0.9962
#
#
# Epoch 17/100
# -------------
# train Loss: 0.0101 Acc: 0.9967
# val Loss: 0.0115 Acc: 0.9970
#
#
# Epoch 18/100
# -------------
# train Loss: 0.0098 Acc: 0.9971
# val Loss: 0.0103 Acc: 0.9970
#
#
# Epoch 19/100
# -------------
# train Loss: 0.0095 Acc: 0.9971
# val Loss: 0.0094 Acc: 0.9974
#
#
# Epoch 20/100
# -------------
# train Loss: 0.0090 Acc: 0.9972
# val Loss: 0.0112 Acc: 0.9970
#
#
# Epoch 21/100
# -------------
# train Loss: 0.0071 Acc: 0.9982
# val Loss: 0.0087 Acc: 0.9970
#
#
# Epoch 22/100
# -------------
# train Loss: 0.0066 Acc: 0.9982
# val Loss: 0.0113 Acc: 0.9970
#
#
# Epoch 23/100
# -------------
# train Loss: 0.0058 Acc: 0.9984
# val Loss: 0.0096 Acc: 0.9966
#
#
# Epoch 24/100
# -------------
# train Loss: 0.0050 Acc: 0.9989
# val Loss: 0.0167 Acc: 0.9949
#
#
# Epoch 25/100
# -------------
# train Loss: 0.0053 Acc: 0.9987
# val Loss: 0.0088 Acc: 0.9974
#
#
# Epoch 26/100
# -------------
# train Loss: 0.0061 Acc: 0.9984
# val Loss: 0.0079 Acc: 0.9966
#
#
# Epoch 27/100
# -------------
# train Loss: 0.0058 Acc: 0.9983
# val Loss: 0.0082 Acc: 0.9979
#
#
# Epoch 28/100
# -------------
# train Loss: 0.0060 Acc: 0.9979
# val Loss: 0.0079 Acc: 0.9970
#
#
# Epoch 29/100
# -------------
# train Loss: 0.0053 Acc: 0.9987
# val Loss: 0.0076 Acc: 0.9974
#
#
# Epoch 30/100
# -------------
# train Loss: 0.0036 Acc: 0.9993
# val Loss: 0.0084 Acc: 0.9974
#
#
# Epoch 31/100
# -------------
# train Loss: 0.0029 Acc: 0.9995
# val Loss: 0.0080 Acc: 0.9979
#
#
# Epoch 32/100
# -------------
# train Loss: 0.0034 Acc: 0.9993
# val Loss: 0.0095 Acc: 0.9979
#
#
# Epoch 33/100
# -------------
# train Loss: 0.0041 Acc: 0.9989
# val Loss: 0.0182 Acc: 0.9962
#
#
# Epoch 34/100
# -------------
# train Loss: 0.0067 Acc: 0.9981
# val Loss: 0.0073 Acc: 0.9974
#
#
# Epoch 35/100
# -------------
# train Loss: 0.0030 Acc: 0.9991
# val Loss: 0.0142 Acc: 0.9949
#
#
# Epoch 36/100
# -------------
# train Loss: 0.0028 Acc: 0.9993
# val Loss: 0.0111 Acc: 0.9970
#
#
# Epoch 37/100
# -------------
# train Loss: 0.0030 Acc: 0.9991
# val Loss: 0.0072 Acc: 0.9979
#
#
# Epoch 38/100
# -------------
# train Loss: 0.0021 Acc: 0.9999
# val Loss: 0.0110 Acc: 0.9974
#
#
# Epoch 39/100
# -------------
# train Loss: 0.0024 Acc: 0.9997
# val Loss: 0.0085 Acc: 0.9979
#
#
# Epoch 40/100
# -------------
# train Loss: 0.0021 Acc: 0.9998
# val Loss: 0.0158 Acc: 0.9932
#
#
# Epoch 41/100
# -------------
# train Loss: 0.0037 Acc: 0.9990
# val Loss: 0.0112 Acc: 0.9966
#
#
# Epoch 42/100
# -------------
# train Loss: 0.0017 Acc: 0.9998
# val Loss: 0.0076 Acc: 0.9979
#
#
# Epoch 43/100
# -------------
# train Loss: 0.0019 Acc: 0.9995
# val Loss: 0.0076 Acc: 0.9979
#
#
# Epoch 44/100
# -------------
# train Loss: 0.0016 Acc: 0.9998
# val Loss: 0.0069 Acc: 0.9979
#
#
# Epoch 45/100
# -------------
# train Loss: 0.0026 Acc: 0.9994
# val Loss: 0.0107 Acc: 0.9970
#
#
# Epoch 46/100
# -------------
# train Loss: 0.0024 Acc: 0.9994
# val Loss: 0.0066 Acc: 0.9974
#
#
# Epoch 47/100
# -------------
# train Loss: 0.0032 Acc: 0.9987
# val Loss: 0.0095 Acc: 0.9974
#
#
# Epoch 48/100
# -------------
# train Loss: 0.0017 Acc: 0.9997
# val Loss: 0.0096 Acc: 0.9970
#
#
# Epoch 49/100
# -------------
# train Loss: 0.0017 Acc: 0.9997
# val Loss: 0.0089 Acc: 0.9974
#
#
# Epoch 50/100
# -------------
# train Loss: 0.0028 Acc: 0.9995
# val Loss: 0.0120 Acc: 0.9970
#
#
# Epoch 51/100
# -------------
# train Loss: 0.0024 Acc: 0.9996
# val Loss: 0.0093 Acc: 0.9970
#
#
# Epoch 52/100
# -------------
# train Loss: 0.0019 Acc: 0.9995
# val Loss: 0.0050 Acc: 0.9983
#
#
# Epoch 53/100
# -------------
# train Loss: 0.0011 Acc: 0.9999
# val Loss: 0.0053 Acc: 0.9983
#
#
# Epoch 54/100
# -------------
# train Loss: 0.0009 Acc: 0.9999
# val Loss: 0.0084 Acc: 0.9983
#
#
# Epoch 55/100
# -------------
# train Loss: 0.0009 Acc: 0.9999
# val Loss: 0.0073 Acc: 0.9983
#
#
# Epoch 56/100
# -------------
# train Loss: 0.0008 Acc: 0.9999
# val Loss: 0.0079 Acc: 0.9983
#
#
# Epoch 57/100
# -------------
# train Loss: 0.0008 Acc: 0.9999
# val Loss: 0.0089 Acc: 0.9970
#
#
# Epoch 58/100
# -------------
# train Loss: 0.0008 Acc: 0.9999
# val Loss: 0.0071 Acc: 0.9983
#
#
# Epoch 59/100
# -------------
# train Loss: 0.0008 Acc: 0.9999
# val Loss: 0.0076 Acc: 0.9983
#
#
# Epoch 60/100
# -------------
# train Loss: 0.0008 Acc: 0.9999
# val Loss: 0.0043 Acc: 0.9983
#
#
# Epoch 61/100
# -------------
# train Loss: 0.0111 Acc: 0.9962
# val Loss: 0.0067 Acc: 0.9974
#
#
# Epoch 62/100
# -------------
# train Loss: 0.0013 Acc: 0.9998
# val Loss: 0.0062 Acc: 0.9983
#
#
# Epoch 63/100
# -------------
# train Loss: 0.0012 Acc: 0.9997
# val Loss: 0.0051 Acc: 0.9983
#
#
# Epoch 64/100
# -------------
# train Loss: 0.0023 Acc: 0.9990
# val Loss: 0.0099 Acc: 0.9974
#
#
# Epoch 65/100
# -------------
# train Loss: 0.0016 Acc: 0.9996
# val Loss: 0.0074 Acc: 0.9983
#
#
# Epoch 66/100
# -------------
# train Loss: 0.0008 Acc: 0.9998
# val Loss: 0.0041 Acc: 0.9979
#
#
# Epoch 67/100
# -------------
# train Loss: 0.0006 Acc: 0.9999
# val Loss: 0.0069 Acc: 0.9979
#
#
# Epoch 68/100
# -------------
# train Loss: 0.0006 Acc: 0.9999
# val Loss: 0.0071 Acc: 0.9979
#
#
# Epoch 69/100
# -------------
# train Loss: 0.0005 Acc: 0.9999
# val Loss: 0.0060 Acc: 0.9983
#
#
# Epoch 70/100
# -------------
# train Loss: 0.0005 Acc: 0.9999
# val Loss: 0.0057 Acc: 0.9983
#
#
# Epoch 71/100
# -------------
# train Loss: 0.0004 Acc: 0.9999
# val Loss: 0.0046 Acc: 0.9983
#
#
# Epoch 72/100
# -------------
# train Loss: 0.0096 Acc: 0.9964
# val Loss: 0.0038 Acc: 0.9991
#
#
# Epoch 73/100
# -------------
# train Loss: 0.0015 Acc: 0.9996
# val Loss: 0.0051 Acc: 0.9987
#
#
# Epoch 74/100
# -------------
# train Loss: 0.0005 Acc: 0.9999
# val Loss: 0.0051 Acc: 0.9987
#
#
# Epoch 75/100
# -------------
# train Loss: 0.0005 Acc: 0.9999
# val Loss: 0.0045 Acc: 0.9987
#
#
# Epoch 76/100
# -------------
# train Loss: 0.0004 Acc: 0.9999
# val Loss: 0.0046 Acc: 0.9987
#
#
# Epoch 77/100
# -------------
# train Loss: 0.0003 Acc: 0.9999
# val Loss: 0.0092 Acc: 0.9974
#
#
# Epoch 78/100
# -------------
# train Loss: 0.0003 Acc: 0.9999
# val Loss: 0.0047 Acc: 0.9987
#
#
# Epoch 79/100
# -------------
# train Loss: 0.0003 Acc: 0.9999
# val Loss: 0.0044 Acc: 0.9991
#
#
# Epoch 80/100
# -------------
# train Loss: 0.0004 Acc: 0.9999
# val Loss: 0.0042 Acc: 0.9991
#
#
# Epoch 81/100
# -------------
# train Loss: 0.0003 Acc: 0.9999
# val Loss: 0.0050 Acc: 0.9991
#
#
# Epoch 82/100
# -------------
# train Loss: 0.0003 Acc: 0.9999
# val Loss: 0.0046 Acc: 0.9991
#
#
# Epoch 83/100
# -------------
# train Loss: 0.0002 Acc: 1.0000
# val Loss: 0.0052 Acc: 0.9987
#
#
# Epoch 84/100
# -------------
# train Loss: 0.0002 Acc: 1.0000
# val Loss: 0.0066 Acc: 0.9983
#
#
# Epoch 85/100
# -------------
# train Loss: 0.0002 Acc: 0.9999
# val Loss: 0.0068 Acc: 0.9979
#
#
# Epoch 86/100
# -------------
# train Loss: 0.0005 Acc: 0.9998
# val Loss: 0.0139 Acc: 0.9970
#
#
# Epoch 87/100
# -------------
# train Loss: 0.0006 Acc: 0.9999
# val Loss: 0.0046 Acc: 0.9991
#
#
# Epoch 88/100
# -------------
# train Loss: 0.0002 Acc: 0.9999
# val Loss: 0.0071 Acc: 0.9987
#
#
# Epoch 89/100
# -------------
# train Loss: 0.0002 Acc: 1.0000
# val Loss: 0.0127 Acc: 0.9962
#
#
# Epoch 90/100
# -------------
# train Loss: 0.0136 Acc: 0.9962
# val Loss: 0.0071 Acc: 0.9983
#
#
# Epoch 91/100
# -------------
# train Loss: 0.0008 Acc: 0.9999
# val Loss: 0.0081 Acc: 0.9983
#
#
# Epoch 92/100
# -------------
# train Loss: 0.0004 Acc: 0.9999
# val Loss: 0.0060 Acc: 0.9983
#
#
# Epoch 93/100
# -------------
# train Loss: 0.0005 Acc: 0.9999
# val Loss: 0.0062 Acc: 0.9983
#
#
# Epoch 94/100
# -------------
# train Loss: 0.0003 Acc: 0.9999
# val Loss: 0.0076 Acc: 0.9979
#
#
# Epoch 95/100
# -------------
# train Loss: 0.0002 Acc: 0.9999
# val Loss: 0.0064 Acc: 0.9983
#
#
# Epoch 96/100
# -------------
# train Loss: 0.0002 Acc: 1.0000
# val Loss: 0.0064 Acc: 0.9983
#
#
# Epoch 97/100
# -------------
# train Loss: 0.0002 Acc: 1.0000
# val Loss: 0.0056 Acc: 0.9983
#
#
# Epoch 98/100
# -------------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0068 Acc: 0.9983
#
#
# Epoch 99/100
# -------------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0072 Acc: 0.9983
#
#
# Epoch 100/100
# -------------
# train Loss: 0.0001 Acc: 1.0000
# val Loss: 0.0064 Acc: 0.9983
# [0.79304847 0.97629677 0.98490646 0.98788265 0.99053997 0.99160289
#  0.99160289 0.99266582 0.99319728 0.99330357 0.9943665  0.99511054
#  0.9957483  0.99627976 0.99659864 0.99723639 0.99670493 0.9971301
#  0.9971301  0.99723639 0.99819303 0.99819303 0.99840561 0.99893707
#  0.99872449 0.99840561 0.99829932 0.99787415 0.99872449 0.99925595
#  0.99946854 0.99925595 0.99893707 0.99808673 0.99914966 0.99925595
#  0.99914966 0.99989371 0.99968112 0.99978741 0.99904337 0.99978741
#  0.99946854 0.99978741 0.99936224 0.99936224 0.99872449 0.99968112
#  0.99968112 0.99946854 0.99957483 0.99946854 0.99989371 0.99989371
#  0.99989371 0.99989371 0.99989371 0.99989371 0.99989371 0.99989371
#  0.99617347 0.99978741 0.99968112 0.99904337 0.99957483 0.99978741
#  0.99989371 0.99989371 0.99989371 0.99989371 0.99989371 0.99638605
#  0.99957483 0.99989371 0.99989371 0.99989371 0.99989371 0.99989371
#  0.99989371 0.99989371 0.99989371 0.99989371 1.         1.
#  0.99989371 0.99978741 0.99989371 0.99989371 1.         0.99617347
#  0.99989371 0.99989371 0.99989371 0.99989371 0.99989371 1.
#  1.         1.         1.         1.        ]
# 学習時間：134.19430136680603

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
inputs = X_test
true = y_test

labels = ["Teams", "Meet", "Zoom",]
net.eval() #推論モード

with torch.set_grad_enabled(False):   # 推論モードでは勾配を算出しない
    # 処理前の時刻
    t1 = time.time()
    # 出力
    outputs = net(inputs)     # 順伝播
    _, preds = torch.max(outputs, 1)  # ラベルを予測

    correct = 0
    for i in range(len(preds)):
      if preds[i] == true[i]:
        correct += 1

    print(correct / len(preds))
    # 処理後の時刻
    t2 = time.time()
    # 経過時間を表示
    elapsed_time = t2-t1
    print(f"推論時間：{elapsed_time}")

    print(classification_report(preds, true,  digits=4))

    disp = ConfusionMatrixDisplay.from_predictions(preds, true, display_labels = labels,include_values = False ,normalize = "true", cmap = 'Greens')
    fig, ax = plt.subplots(figsize = (10,10))
    plt.title('confusion matrix')
    disp.plot(ax=ax, cmap="Greens")
# Out:
# 0.9965986394557823
# 推論時間：0.16747260093688965
#               precision    recall  f1-score   support
#
#            0     0.9955    0.9973    0.9964      1103
#            1     1.0000    0.9961    0.9981       775
#            2     0.9953    0.9962    0.9958      1062
#
#     accuracy                         0.9966      2940
#    macro avg     0.9969    0.9965    0.9967      2940
# weighted avg     0.9966    0.9966    0.9966      2940

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
inputs = X_test
true = y_test

labels = ["ipad", "iphone", "laptop", "desktop"]
net.eval() #推論モード

with torch.set_grad_enabled(False):   # 推論モードでは勾配を算出しない
    # 処理前の時刻
    t1 = time.time()
    # 出力
    outputs = net(inputs)     # 順伝播
    _, preds = torch.max(outputs, 1)  # ラベルを予測

    correct = 0
    for i in range(len(preds)):
      if preds[i] == true[i]:
        correct += 1

    print(correct / len(preds))
    # 処理後の時刻
    t2 = time.time()
    # 経過時間を表示
    elapsed_time = t2-t1
    print(f"推論時間：{elapsed_time}")

    print(classification_report(preds, true,  digits=4))

    disp = ConfusionMatrixDisplay.from_predictions(preds, true, display_labels = labels,include_values = False ,normalize = "true", cmap = 'Greens')
    fig, ax = plt.subplots(figsize = (10,10))
    plt.title('confusion matrix')
    disp.plot(ax=ax, cmap="Greens")
# Out:
# 0.8961165048543689
# 推論時間：0.023493051528930664
#               precision    recall  f1-score   support
#
#            0     0.9219    0.8429    0.8806       280
#            1     0.9094    0.9277    0.9185       249
#            2     0.9211    0.9554    0.9380       269
#            3     0.8257    0.8578    0.8414       232
#
#     accuracy                         0.8961      1030
#    macro avg     0.8945    0.8959    0.8946      1030
# weighted avg     0.8970    0.8961    0.8959      1030
